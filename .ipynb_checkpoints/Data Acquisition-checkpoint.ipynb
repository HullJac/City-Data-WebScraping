# %%
import time
import random
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # 2.1 Produce the list of neighborhood names along with their URL's

# %%
url ='http://www.city-data.com/indexes/neighborhoods/FL/1/'
p = requests.get(url)
b = BeautifulSoup(p.content, "html.parser")

# %%
Hoods = b.find(class_ = 'index')
Hoods_links=Hoods.find_all('a')
#Hoods_links

# %%
links=[]
for link in Hoods_links:
    if link.get('href').__contains__('Tampa')==True:
        link='http://www.city-data.com'+link.get('href')
        links.append(link)
#links

# %%
Names=[]
for link in Hoods_links:
    if link.get('href').__contains__('Tampa')==True:
        x=link.get('href')
        x=x[14:-14]
        Names.append(x)
#Names

# %%
def Names_and_urls(url):
    p = requests.get(url)
    b = BeautifulSoup(p.content, "html.parser")
    column_names=['Name','Link']
    Links_Names=[]
    Hoods = b.find(class_ = 'index')
    Hoods_links=Hoods.find_all('a')
    
    for link in Hoods_links:
        if link.get('href').__contains__('Tampa')==True:
            x=link.get('href')
            x=x[14:-14]
            if link.get('href').__contains__('Tampa')==True:
                Link='http://www.city-data.com'+link.get('href')
                d = dict(zip(column_names,[x,Link]))
                Links_Names.append(d)
    return Links_Names

#Names_and_urls('http://www.city-data.com/indexes/neighborhoods/FL/1/')

# %%
url = 'http://www.city-data.com/indexes/neighborhoods/FL/%d/'

l = []
for page in range(1,134):
    print(url%page)
    l = l + Names_and_urls(url%page)
    time.sleep(2)

# %%
l

# %%
df=pd.DataFrame(l)
df.set_index('Name', inplace=True)
df.to_csv('LinksandNames.csv')
df.shape
# Out:
# (2393, 1)

# %%
# %cat LinksandNames.csv | head -10
# Out:
# Name,Link
# 1000-Channelside-Condo,http://www.city-data.com/neighborhood/1000-Channelside-Condo-Tampa-FL.html
# 1301-Soho-Condo,http://www.city-data.com/neighborhood/1301-Soho-Condo-Tampa-FL.html
# 1508-South-Howard-Condo,http://www.city-data.com/neighborhood/1508-South-Howard-Condo-Tampa-FL.html
# 1611-6th-Avenue-Townhomes,http://www.city-data.com/neighborhood/1611-6th-Avenue-Townhomes-Tampa-FL.html
# 2002-Dekle-Condo,http://www.city-data.com/neighborhood/2002-Dekle-Condo-Tampa-FL.html
# 215-Verne-Condo,http://www.city-data.com/neighborhood/215-Verne-Condo-Tampa-FL.html
# 2513-Maryland-Avenue-Condo,http://www.city-data.com/neighborhood/2513-Maryland-Avenue-Condo-Tampa-FL.html
# 2515-Maryland-Avenue-Condo,http://www.city-data.com/neighborhood/2515-Maryland-Avenue-Condo-Tampa-FL.html
# 2518-W-Kansas-Avenue-Condo,http://www.city-data.com/neighborhood/2518-W-Kansas-Avenue-Condo-Tampa-FL.html
# cat: write error: Broken pipe

# %% [markdown]
# # 2.2 Scrape neighborhood data based on URL

# %%
url ='http://www.city-data.com/neighborhood/Alice-Kelly-s-Tampa-FL.html'
p = requests.get(url)
b = BeautifulSoup(p.content, "html.parser")

# %%
for item in l:
    x=item
    for item in x.values():
        links2.append(item)
names=links2[0::2]
#names

# %%
#gets the area and population
def area_population(url):
    try:
        p = requests.get(url)
        b = BeautifulSoup(p.content, "html.parser")
        first=b.find(class_='row')
        second=first.find(class_='content-item')
        third=second.text.split('\n')
        fourth=third[0].split(' ')
        fifth=fourth[1:]
        space=' '
        area=space.join(fifth)

        sixth=third[1].split(' ')
        population=sixth[1]
        return [area,population]
    except:
        return ['NA','NA']
area_population('http://www.city-data.com/neighborhood/Alice-Kelly-s-Tampa-FL.html')

# %%
#Finding area to search for data
first=b.find(class_='row')
second=first.find_all(class_='content-item')
third=first.find_all(class_='hgraph')
third[0]

# %%
#finds specific data I want
third[0].find_all('tr')[0].find_all('td')[1].text

# %%
#fuction to get all the fields of data that I want
def parse_neigh(url):
    data=[]
    p = requests.get(url)
    b = BeautifulSoup(p.content, "html.parser")
    first=b.find(class_='row')
    second=first.find_all(class_='content-item')
    third=first.find_all(class_='hgraph')
    for ind in range(0,23):
        try:
            x=third[ind].find_all('tr')[0].find_all('td')[1].text
            data.append(x)
        except:
            data.append('NA')
    return data
#parse_neigh('http://www.city-data.com/neighborhood/Alice-Kelly-s-Tampa-FL.html')

# %%
#Turning my data into a dictionary

def data_acquisition(url,name):
    values = [name]+area_population(url)+parse_neigh(url)
    keys = ['Neighborhood Name',
        'Area',
        'Population',
        'Population density',
        'Median household income',
        'Median rent',
        'Population of males'
        'Median age of males',
        'Median age of females',
        'Average household size',
        'Percentage of mamily households',
        'Percentage of married-couple families',
        'Percentage of married-couple families with children',
        'Percentage of single mother households',
        'Percentage of never married males Over 15',
        'Percentage of never married females Over 15',
        'Percentage of people that do not speak english',
        'Percentage of people born in the state',
        'Percentage of people born in another state',
        'Percentage of native residents born outside the US',
        'Percentage of foreign born residents',
        'Average number of vehicles per house/condo',
        'Average number of vehicles per apartment',
        'Percentage of units with a mortgage',
        'Crime index for the city',
        'Percentage of males in managment positions',]
    d = dict(zip(keys,values))
    total_data.append(d)

# %%
#data_acquisition('http://www.city-data.com/neighborhood/1000-Channelside-Condo-Tampa-FL.html','name')

# %% [markdown]
# # 2.3 Scraping all the neighborhoods

# %%
#clears total_data

total_data=[]

# %%
#Obtains all the links to neighborhoods in Tampa
links2=[]
for item in l:
    x=item
    for item in x.values():
        links2.append(item)
links3=links2[1::2]
#links3

# %%
#goes though all the links and adds the name to them and scrapes the data from every site
c=48
for link in links3[0:1000]:
    x=random.randint(2,6)
    data_acquisition(link,names[c])
    time.sleep(x)
    c+=1
    print('done')
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# /opt/anaconda3/envs/jh/lib/python3.5/http/client.py in getresponse(self)
#    1197             try:
# -> 1198                 response.begin()
#    1199             except ConnectionError:
#
# /opt/anaconda3/envs/jh/lib/python3.5/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /opt/anaconda3/envs/jh/lib/python3.5/http/client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# /opt/anaconda3/envs/jh/lib/python3.5/socket.py in readinto(self, b)
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     356             if read is False or not self._is_method_retryable(method):
# --> 357                 raise six.reraise(type(error), error, _stacktrace)
#     358             elif read is not None:
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# /opt/anaconda3/envs/jh/lib/python3.5/http/client.py in getresponse(self)
#    1197             try:
# -> 1198                 response.begin()
#    1199             except ConnectionError:
#
# /opt/anaconda3/envs/jh/lib/python3.5/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /opt/anaconda3/envs/jh/lib/python3.5/http/client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# /opt/anaconda3/envs/jh/lib/python3.5/socket.py in readinto(self, b)
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-487-c7d1b77bd315> in <module>()
#       3 for link in links3[0:1000]:
#       4     x=random.randint(2,6)
# ----> 5     data_acquisition(link,names[c])
#       6     time.sleep(x)
#       7     c+=1
#
# <ipython-input-476-5171913d2b72> in data_acquisition(url, name)
#       2
#       3 def data_acquisition(url,name):
# ----> 4     values = [name]+area_population(url)+parse_neigh(url)
#       5     keys = ['Neighborhood Name',
#       6         'Area',
#
# <ipython-input-475-95d993c9bc33> in parse_neigh(url)
#       2 def parse_neigh(url):
#       3     data=[]
# ----> 4     p = requests.get(url)
#       5     b = BeautifulSoup(p.content, "html.parser")
#       6     first=b.find(class_='row')
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/envs/jh/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488
#     489         except (ProtocolError, socket.error) as err:
# --> 490             raise ConnectionError(err, request=request)
#     491
#     492         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))

# %%
total_data
# Out:
# [{'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': '1000-Channelside-Condo',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': '1301-Soho-Condo',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': '1508-South-Howard-Condo',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': 'NA',
#   'Average household size': '34.9%',
#   'Average number of vehicles per apartment': '8.5%',
#   'Average number of vehicles per house/condo': '2.2%',
#   'Crime index for the city': '3.6%',
#   'Median age of females': '13.2%',
#   'Median household income': '$880',
#   'Median rent': '1.6 people',
#   'Neighborhood Name': '1611-6th-Avenue-Townhomes',
#   'Percentage of foreign born residents': '7.7%',
#   'Percentage of males in managment positions': '2.2%',
#   'Percentage of mamily households': '24.4%',
#   'Percentage of married-couple families': '48.0%',
#   'Percentage of married-couple families with children': '32.5%',
#   'Percentage of native residents born outside the US': '22.0%',
#   'Percentage of never married females Over 15': '1.3',
#   'Percentage of never married males Over 15': '12.3%',
#   'Percentage of people born in another state': '242.5',
#   'Percentage of people born in the state': '56.1%',
#   'Percentage of people that do not speak english': '1.1',
#   'Percentage of single mother households': '7.2%',
#   'Percentage of units with a mortgage': '1.5%',
#   'Population': 'NA',
#   'Population density': '$55,643',
#   'Population of malesMedian age of males': '12.2%'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': '2002-Dekle-Condo',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': '1',
#   'Average household size': '26.5%',
#   'Average number of vehicles per apartment': '242.5',
#   'Average number of vehicles per house/condo': '89.7%',
#   'Crime index for the city': '16.5%',
#   'Median age of females': '27.1%',
#   'Median household income': '$94,049',
#   'Median rent': '$1,267',
#   'Neighborhood Name': '215-Verne-Condo',
#   'Percentage of foreign born residents': '1.6',
#   'Percentage of males in managment positions': '6.0%',
#   'Percentage of mamily households': '35.0%',
#   'Percentage of married-couple families': '37.4%',
#   'Percentage of married-couple families with children': '26.3%',
#   'Percentage of native residents born outside the US': '1.7',
#   'Percentage of never married females Over 15': '30.1%',
#   'Percentage of never married males Over 15': '0.0%',
#   'Percentage of people born in another state': '8.3%',
#   'Percentage of people born in the state': '3.0%',
#   'Percentage of people that do not speak english': '58.5%',
#   'Percentage of single mother households': '28.7%',
#   'Percentage of units with a mortgage': '29.2%',
#   'Population': 'density:215',
#   'Population density': '1,709 people per square mile',
#   'Population of malesMedian age of males': '1.9 people'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': '2513-Maryland-Avenue-Condo',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': '2515-Maryland-Avenue-Condo',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': '2518-W-Kansas-Avenue-Condo',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': '2525-Maryland-Avenue-Condo',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': '2527-Maryland-Avenue-Condo',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': '2',
#   'Average household size': '42.2 years',
#   'Average number of vehicles per apartment': '1.4',
#   'Average number of vehicles per house/condo': '6.9%',
#   'Crime index for the city': '89.7%',
#   'Median age of females': '29.4 years',
#   'Median household income': '$209,167',
#   'Median rent': '$1,168',
#   'Neighborhood Name': '2807-Estrella-Avenue-Condo',
#   'Percentage of foreign born residents': '0.4%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '3.2 people',
#   'Percentage of married-couple families': '79.9%',
#   'Percentage of married-couple families with children': '85.8%',
#   'Percentage of native residents born outside the US': '48.8%',
#   'Percentage of never married females Over 15': '11.4%',
#   'Percentage of never married males Over 15': '1.4%',
#   'Percentage of people born in another state': '43.9%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '4.7%',
#   'Percentage of single mother households': '37.9%',
#   'Percentage of units with a mortgage': '5.2',
#   'Population': 'density:2807',
#   'Population density': '9,259 people per square mile',
#   'Population of malesMedian age of males': '1'},
#  {'Area': '0.017 square miles',
#   'Average household size': '27.8 years',
#   'Average number of vehicles per apartment': '1.6',
#   'Average number of vehicles per house/condo': '12.5%',
#   'Crime index for the city': '69.1%',
#   'Median age of females': '25.6 years',
#   'Median household income': '$34,397',
#   'Median rent': '$744',
#   'Neighborhood Name': '301-Mobile-Villa',
#   'Percentage of foreign born residents': '7.8%',
#   'Percentage of males in managment positions': '$199,167',
#   'Percentage of mamily households': '37.0 people',
#   'Percentage of married-couple families': '56.8%',
#   'Percentage of married-couple families with children': '37.1%',
#   'Percentage of native residents born outside the US': '32.5%',
#   'Percentage of never married females Over 15': '20.5%',
#   'Percentage of never married males Over 15': '11.7%',
#   'Percentage of people born in another state': '47.2%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '22.8%',
#   'Percentage of single mother households': '21.0%',
#   'Percentage of units with a mortgage': '1.2',
#   'Population': '27',
#   'Population density': '1,565 people per square mile',
#   'Population of malesMedian age of males': '14'},
#  {'Area': '2',
#   'Average household size': '33.4 years',
#   'Average number of vehicles per apartment': '2.0',
#   'Average number of vehicles per house/condo': '7.2%',
#   'Crime index for the city': '86.1%',
#   'Median age of females': '29.0 years',
#   'Median household income': '$93,125',
#   'Median rent': '$1,042',
#   'Neighborhood Name': '3014-Palmira-Office-Condo',
#   'Percentage of foreign born residents': '1.3%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '2.8 people',
#   'Percentage of married-couple families': '65.6%',
#   'Percentage of married-couple families with children': '66.5%',
#   'Percentage of native residents born outside the US': '44.2%',
#   'Percentage of never married females Over 15': '19.6%',
#   'Percentage of never married males Over 15': '3.9%',
#   'Percentage of people born in another state': '47.3%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '4.0%',
#   'Percentage of single mother households': '40.5%',
#   'Percentage of units with a mortgage': '1.8',
#   'Population': 'density:3014',
#   'Population density': '3,797 people per square mile',
#   'Population of malesMedian age of males': '1'},
#  {'Area': '4',
#   'Average household size': '32.3 years',
#   'Average number of vehicles per apartment': '1.5',
#   'Average number of vehicles per house/condo': '11.2%',
#   'Crime index for the city': '74.6%',
#   'Median age of females': '27.9 years',
#   'Median household income': '$92,303',
#   'Median rent': '$1,466',
#   'Neighborhood Name': '305-South-Westland-Condo',
#   'Percentage of foreign born residents': '0.4%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '21.0 people',
#   'Percentage of married-couple families': '13.9%',
#   'Percentage of married-couple families with children': '16.5%',
#   'Percentage of native residents born outside the US': '56.3%',
#   'Percentage of never married females Over 15': '31.6%',
#   'Percentage of never married males Over 15': '4.7%',
#   'Percentage of people born in another state': '32.2%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '33.0%',
#   'Percentage of single mother households': '45.9%',
#   'Percentage of units with a mortgage': '1.6',
#   'Population': 'density:305',
#   'Population density': '14,468 people per square mile',
#   'Population of malesMedian age of males': '2'},
#  {'Area': '3',
#   'Average household size': '25.8 years',
#   'Average number of vehicles per apartment': '1.2',
#   'Average number of vehicles per house/condo': '11.2%',
#   'Crime index for the city': '70.3%',
#   'Median age of females': '29.5 years',
#   'Median household income': '$60,152',
#   'Median rent': '$1,066',
#   'Neighborhood Name': '306-South-Fremont-Condo',
#   'Percentage of foreign born residents': '0.4%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '1.8 people',
#   'Percentage of married-couple families': '5.1%',
#   'Percentage of married-couple families with children': '8.0%',
#   'Percentage of native residents born outside the US': '56.3%',
#   'Percentage of never married females Over 15': '39.0%',
#   'Percentage of never married males Over 15': '11.5%',
#   'Percentage of people born in another state': '32.2%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '34.1%',
#   'Percentage of single mother households': '50.6%',
#   'Percentage of units with a mortgage': '1.4',
#   'Population': 'density:306',
#   'Population density': '11,059 people per square mile',
#   'Population of malesMedian age of males': '2'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': '30th-Street-Professional-Building-Condo',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': '2',
#   'Average household size': '34.4 years',
#   'Average number of vehicles per apartment': '1.8',
#   'Average number of vehicles per house/condo': '9.1%',
#   'Crime index for the city': '52.5%',
#   'Median age of females': '48.3 years',
#   'Median household income': '$75,091',
#   'Median rent': '$1,230',
#   'Neighborhood Name': '310-S-Arrawana-Avenue-Condo',
#   'Percentage of foreign born residents': '4.5%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '2.2 people',
#   'Percentage of married-couple families': '46.3%',
#   'Percentage of married-couple families with children': '56.4%',
#   'Percentage of native residents born outside the US': '41.0%',
#   'Percentage of never married females Over 15': '7.9%',
#   'Percentage of never married males Over 15': '0.7%',
#   'Percentage of people born in another state': '45.4%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '10.1%',
#   'Percentage of single mother households': '54.3%',
#   'Percentage of units with a mortgage': '1.7',
#   'Population': 'density:310',
#   'Population density': '3,663 people per square mile',
#   'Population of malesMedian age of males': '0'},
#  {'Area': '6',
#   'Average household size': '26.6 years',
#   'Average number of vehicles per apartment': '1.5',
#   'Average number of vehicles per house/condo': '9.1%',
#   'Crime index for the city': '81.6%',
#   'Median age of females': '43.0 years',
#   'Median household income': '$111,292',
#   'Median rent': '$898',
#   'Neighborhood Name': '311-Gomez-Condo',
#   'Percentage of foreign born residents': '4.5%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '2.1 people',
#   'Percentage of married-couple families': '23.1%',
#   'Percentage of married-couple families with children': '21.9%',
#   'Percentage of native residents born outside the US': '41.0%',
#   'Percentage of never married females Over 15': '13.3%',
#   'Percentage of never married males Over 15': '3.9%',
#   'Percentage of people born in another state': '45.4%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '50.6%',
#   'Percentage of single mother households': '34.8%',
#   'Percentage of units with a mortgage': '1.2',
#   'Population': 'density:311',
#   'Population density': '22,783 people per square mile',
#   'Population of malesMedian age of males': '1'},
#  {'Area': '1',
#   'Average household size': '66.3 years',
#   'Average number of vehicles per apartment': '0.9',
#   'Average number of vehicles per house/condo': '1.2',
#   'Crime index for the city': '242.5',
#   'Median age of females': '35.0 years',
#   'Median household income': '$16,750',
#   'Median rent': '$388',
#   'Neighborhood Name': '3219-Deleon-Street-Condo',
#   'Percentage of foreign born residents': '9.1%',
#   'Percentage of males in managment positions': '7.8%',
#   'Percentage of mamily households': '1.4 people',
#   'Percentage of married-couple families': '27.6%',
#   'Percentage of married-couple families with children': '11.7%',
#   'Percentage of native residents born outside the US': '4.5%',
#   'Percentage of never married females Over 15': '30.9%',
#   'Percentage of never married males Over 15': '6.4%',
#   'Percentage of people born in another state': '41.0%',
#   'Percentage of people born in the state': '45.4%',
#   'Percentage of people that do not speak english': '19.9%',
#   'Percentage of single mother households': '117.0%',
#   'Percentage of units with a mortgage': '78.3%',
#   'Population': 'density:3219',
#   'Population density': '4,557 people per square mile',
#   'Population of malesMedian age of males': '1'},
#  {'Area': '1',
#   'Average household size': '66.3 years',
#   'Average number of vehicles per apartment': '1.2',
#   'Average number of vehicles per house/condo': '9.1%',
#   'Crime index for the city': '78.3%',
#   'Median age of females': '35.0 years',
#   'Median household income': '$16,750',
#   'Median rent': '$388',
#   'Neighborhood Name': '3221-Deleon-Street-Condo',
#   'Percentage of foreign born residents': '4.5%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '1.4 people',
#   'Percentage of married-couple families': '27.6%',
#   'Percentage of married-couple families with children': '11.7%',
#   'Percentage of native residents born outside the US': '41.0%',
#   'Percentage of never married females Over 15': '30.9%',
#   'Percentage of never married males Over 15': '6.4%',
#   'Percentage of people born in another state': '45.4%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '19.9%',
#   'Percentage of single mother households': '117.0%',
#   'Percentage of units with a mortgage': '0.9',
#   'Population': 'density:3221',
#   'Population density': '4,346 people per square mile',
#   'Population of malesMedian age of males': '1'},
#  {'Area': '0.005 square miles',
#   'Average household size': '26.8 years',
#   'Average number of vehicles per apartment': '1.7',
#   'Average number of vehicles per house/condo': '8.3%',
#   'Crime index for the city': '89.7%',
#   'Median age of females': '40.4 years',
#   'Median household income': '$94,049',
#   'Median rent': '$1,267',
#   'Neighborhood Name': '345-Bayshore-Condo',
#   'Percentage of foreign born residents': '3.0%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '1.9 people',
#   'Percentage of married-couple families': '27.1%',
#   'Percentage of married-couple families with children': '26.5%',
#   'Percentage of native residents born outside the US': '58.5%',
#   'Percentage of never married females Over 15': '26.3%',
#   'Percentage of never married males Over 15': '21.4%',
#   'Percentage of people born in another state': '30.1%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '28.7%',
#   'Percentage of single mother households': '20.0%',
#   'Percentage of units with a mortgage': '1.6',
#   'Population': '21',
#   'Population density': '4,316 people per square mile',
#   'Population of malesMedian age of males': '9'},
#  {'Area': '1',
#   'Average household size': '20.7%',
#   'Average number of vehicles per apartment': '242.5',
#   'Average number of vehicles per house/condo': '55.8%',
#   'Crime index for the city': '23.6%',
#   'Median age of females': '12.3%',
#   'Median household income': '$51,417',
#   'Median rent': '$885',
#   'Neighborhood Name': '4218-W-No-B-Street-Condo',
#   'Percentage of foreign born residents': '1.2',
#   'Percentage of males in managment positions': '5.8%',
#   'Percentage of mamily households': '70.2%',
#   'Percentage of married-couple families': '22.7%',
#   'Percentage of married-couple families with children': '34.7%',
#   'Percentage of native residents born outside the US': '1.5',
#   'Percentage of never married females Over 15': '34.2%',
#   'Percentage of never married males Over 15': '0.0%',
#   'Percentage of people born in another state': '26.5%',
#   'Percentage of people born in the state': '7.3%',
#   'Percentage of people that do not speak english': '31.9%',
#   'Percentage of single mother households': '16.1%',
#   'Percentage of units with a mortgage': '10.3%',
#   'Population': 'density:4218',
#   'Population density': '2,032 people per square mile',
#   'Population of malesMedian age of males': '1.7 people'},
#  {'Area': '0.004 square miles',
#   'Average household size': '28.7 years',
#   'Average number of vehicles per apartment': '1.7',
#   'Average number of vehicles per house/condo': '39.3%',
#   'Crime index for the city': '34.1%',
#   'Median age of females': '30.2 years',
#   'Median household income': '$25,500',
#   'Median rent': '$689',
#   'Neighborhood Name': '4710-Medical-Arts-Condo',
#   'Percentage of foreign born residents': '9.4%',
#   'Percentage of males in managment positions': '$121,822',
#   'Percentage of mamily households': '2.2 people',
#   'Percentage of married-couple families': '39.4%',
#   'Percentage of married-couple families with children': '30.9%',
#   'Percentage of native residents born outside the US': '22.1%',
#   'Percentage of never married females Over 15': '12.6%',
#   'Percentage of never married males Over 15': '16.9%',
#   'Percentage of people born in another state': '29.2%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '20.3%',
#   'Percentage of single mother households': '43.3%',
#   'Percentage of units with a mortgage': '1.1',
#   'Population': '8',
#   'Population density': '2,091 people per square mile',
#   'Population of malesMedian age of males': '3'},
#  {'Area': '0.002 square miles',
#   'Average household size': '60.5%',
#   'Average number of vehicles per apartment': '242.5',
#   'Average number of vehicles per house/condo': '67.2%',
#   'Crime index for the city': '3.7%',
#   'Median age of females': '50.7%',
#   'Median household income': '$68,875',
#   'Median rent': '$1,034',
#   'Neighborhood Name': '5010-Bayshore-Condo',
#   'Percentage of foreign born residents': '1.8',
#   'Percentage of males in managment positions': '4.8%',
#   'Percentage of mamily households': '58.9%',
#   'Percentage of married-couple families': '1.5%',
#   'Percentage of married-couple families with children': '11.4%',
#   'Percentage of native residents born outside the US': '1.8',
#   'Percentage of never married females Over 15': '38.0%',
#   'Percentage of never married males Over 15': '0.0%',
#   'Percentage of people born in another state': '5.8%',
#   'Percentage of people born in the state': '8.2%',
#   'Percentage of people that do not speak english': '47.9%',
#   'Percentage of single mother households': '13.4%',
#   'Percentage of units with a mortgage': '4.5%',
#   'Population': '1',
#   'Population density': '404 people per square mile',
#   'Population of malesMedian age of males': '2.4 people'},
#  {'Area': '3',
#   'Average household size': '36.5 years',
#   'Average number of vehicles per apartment': '1.6',
#   'Average number of vehicles per house/condo': '22.0%',
#   'Crime index for the city': '58.5%',
#   'Median age of females': '44.8 years',
#   'Median household income': '$35,000',
#   'Median rent': '$906',
#   'Neighborhood Name': '502-North-Armenia-Condo',
#   'Percentage of foreign born residents': '3.0%',
#   'Percentage of males in managment positions': '$155,731',
#   'Percentage of mamily households': '2.7 people',
#   'Percentage of married-couple families': '44.7%',
#   'Percentage of married-couple families with children': '33.7%',
#   'Percentage of native residents born outside the US': '26.9%',
#   'Percentage of never married females Over 15': '13.2%',
#   'Percentage of never married males Over 15': '3.4%',
#   'Percentage of people born in another state': '48.1%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '36.5%',
#   'Percentage of single mother households': '37.6%',
#   'Percentage of units with a mortgage': '1.3',
#   'Population': 'density:502',
#   'Population density': '8,474 people per square mile',
#   'Population of malesMedian age of males': '1'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': '56th-and-Fletcher-Office-Park',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': '0.002 square miles',
#   'Average household size': '25.9%',
#   'Average number of vehicles per apartment': '242.5',
#   'Average number of vehicles per house/condo': '52.5%',
#   'Crime index for the city': '11.4%',
#   'Median age of females': '32.2%',
#   'Median household income': '$66,607',
#   'Median rent': '$1,539',
#   'Neighborhood Name': '5700-Mariner-Condo-Apartments-South',
#   'Percentage of foreign born residents': '1.2',
#   'Percentage of males in managment positions': '13.3%',
#   'Percentage of mamily households': '51.7%',
#   'Percentage of married-couple families': '33.8%',
#   'Percentage of married-couple families with children': '24.3%',
#   'Percentage of native residents born outside the US': '1.5',
#   'Percentage of never married females Over 15': '44.7%',
#   'Percentage of never married males Over 15': '0.0%',
#   'Percentage of people born in another state': '7.7%',
#   'Percentage of people born in the state': '2.1%',
#   'Percentage of people that do not speak english': '45.4%',
#   'Percentage of single mother households': '22.1%',
#   'Percentage of units with a mortgage': '41.8%',
#   'Population': '1',
#   'Population density': '583 people per square mile',
#   'Population of malesMedian age of males': '1.8 people'},
#  {'Area': '1',
#   'Average household size': '13.2%',
#   'Average number of vehicles per apartment': '22.0%',
#   'Average number of vehicles per house/condo': '242.5',
#   'Crime index for the city': '2.2%',
#   'Median age of females': '12.2%',
#   'Median household income': '$55,643',
#   'Median rent': '$880',
#   'Neighborhood Name': '5th-Avenue-Lofts-Condo',
#   'Percentage of foreign born residents': '56.1%',
#   'Percentage of males in managment positions': '8.5%',
#   'Percentage of mamily households': '2.4%',
#   'Percentage of married-couple families': '63.0%',
#   'Percentage of married-couple families with children': '34.9%',
#   'Percentage of native residents born outside the US': '1.1',
#   'Percentage of never married females Over 15': '32.5%',
#   'Percentage of never married males Over 15': '48.0%',
#   'Percentage of people born in another state': '1.3',
#   'Percentage of people born in the state': '12.3%',
#   'Percentage of people that do not speak english': '7.2%',
#   'Percentage of single mother households': '24.4%',
#   'Percentage of units with a mortgage': '7.7%',
#   'Population': 'density:5th',
#   'Population density': '3,143 people per square mile',
#   'Population of malesMedian age of males': '1.6 people'},
#  {'Area': '0.002 square miles',
#   'Average household size': '36.3 years',
#   'Average number of vehicles per apartment': '1.4',
#   'Average number of vehicles per house/condo': '19.3%',
#   'Crime index for the city': '54.5%',
#   'Median age of females': '43.8 years',
#   'Median household income': '$35,375',
#   'Median rent': '$641',
#   'Neighborhood Name': '9th-Street-Villas-Condo',
#   'Percentage of foreign born residents': '11.3%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '2.5 people',
#   'Percentage of married-couple families': '49.6%',
#   'Percentage of married-couple families with children': '36.8%',
#   'Percentage of native residents born outside the US': '24.1%',
#   'Percentage of never married females Over 15': '13.1%',
#   'Percentage of never married males Over 15': '25.6%',
#   'Percentage of people born in another state': '45.3%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '23.4%',
#   'Percentage of single mother households': '11.6%',
#   'Percentage of units with a mortgage': '1.1',
#   'Population': '4',
#   'Population density': '1,853 people per square mile',
#   'Population of malesMedian age of males': '2'},
#  {'Area': '1',
#   'Average household size': '34.9%',
#   'Average number of vehicles per apartment': '2.1%',
#   'Average number of vehicles per house/condo': '242.5',
#   'Crime index for the city': '16.5%',
#   'Median age of females': '46.6%',
#   'Median household income': '$23,493',
#   'Median rent': '$563',
#   'Neighborhood Name': 'A-D-Apartments-Condo',
#   'Percentage of foreign born residents': '40.9%',
#   'Percentage of males in managment positions': '21.7%',
#   'Percentage of mamily households': '24.2%',
#   'Percentage of married-couple families': '12.4%',
#   'Percentage of married-couple families with children': '29.6%',
#   'Percentage of native residents born outside the US': '0.9',
#   'Percentage of never married females Over 15': '21.9%',
#   'Percentage of never married males Over 15': '33.6%',
#   'Percentage of people born in another state': '1.6',
#   'Percentage of people born in the state': '36.4%',
#   'Percentage of people that do not speak english': '8.1%',
#   'Percentage of single mother households': '9.8%',
#   'Percentage of units with a mortgage': '32.7%',
#   'Population': 'density:A',
#   'Population density': '1,445 people per square mile',
#   'Population of malesMedian age of males': '2.4 people'},
#  {'Area': 'NA',
#   'Average household size': '32.0%',
#   'Average number of vehicles per apartment': '12.0%',
#   'Average number of vehicles per house/condo': '16.9%',
#   'Crime index for the city': '26.4%',
#   'Median age of females': '10.7%',
#   'Median household income': '$911',
#   'Median rent': '1.3 people',
#   'Neighborhood Name': 'Abbey-Road-at-Old-Hyde-Park-Condo',
#   'Percentage of foreign born residents': '32.0%',
#   'Percentage of males in managment positions': '45.3%',
#   'Percentage of mamily households': '34.9%',
#   'Percentage of married-couple families': '30.1%',
#   'Percentage of married-couple families with children': '58.5%',
#   'Percentage of native residents born outside the US': '59.2%',
#   'Percentage of never married females Over 15': '1.6',
#   'Percentage of never married males Over 15': '8.3%',
#   'Percentage of people born in another state': '242.5',
#   'Percentage of people born in the state': '36.8%',
#   'Percentage of people that do not speak english': '1.2',
#   'Percentage of single mother households': '3.0%',
#   'Percentage of units with a mortgage': '22.4%',
#   'Population': 'NA',
#   'Population density': '$52,778',
#   'Population of malesMedian age of males': '20.7%'},
#  {'Area': '1',
#   'Average household size': '31.2 years',
#   'Average number of vehicles per apartment': '1.3',
#   'Average number of vehicles per house/condo': '9.1%',
#   'Crime index for the city': '71.1%',
#   'Median age of females': '42.0 years',
#   'Median household income': '$59,050',
#   'Median rent': '$838',
#   'Neighborhood Name': 'Aberdeen-On-Glen',
#   'Percentage of foreign born residents': '4.5%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '1.5 people',
#   'Percentage of married-couple families': '26.1%',
#   'Percentage of married-couple families with children': '22.6%',
#   'Percentage of native residents born outside the US': '41.0%',
#   'Percentage of never married females Over 15': '29.9%',
#   'Percentage of never married males Over 15': '4.3%',
#   'Percentage of people born in another state': '45.4%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '15.9%',
#   'Percentage of single mother households': '79.0%',
#   'Percentage of units with a mortgage': '1.4',
#   'Population': 'density:Aberdeen',
#   'Population density': '3,026 people per square mile',
#   'Population of malesMedian age of males': '1'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': 'Adalia-Bayfront-Condo',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': '0.092 square miles',
#   'Average household size': '55.1 years',
#   'Average number of vehicles per apartment': '2.0',
#   'Average number of vehicles per house/condo': '32.6%',
#   'Crime index for the city': '52.5%',
#   'Median age of females': '51.1 years',
#   'Median household income': '$38,596',
#   'Median rent': '$854',
#   'Neighborhood Name': 'Adamo-Acres',
#   'Percentage of foreign born residents': '4.3%',
#   'Percentage of males in managment positions': '$77,203',
#   'Percentage of mamily households': '3.7 people',
#   'Percentage of married-couple families': '48.9%',
#   'Percentage of married-couple families with children': '42.9%',
#   'Percentage of native residents born outside the US': '19.8%',
#   'Percentage of never married females Over 15': '18.9%',
#   'Percentage of never married males Over 15': '10.4%',
#   'Percentage of people born in another state': '43.4%',
#   'Percentage of people born in the state': '22.6%',
#   'Percentage of people that do not speak english': '20.2%',
#   'Percentage of single mother households': '16.8%',
#   'Percentage of units with a mortgage': '1.0',
#   'Population': '221',
#   'Population density': '2,412 people per square mile',
#   'Population of malesMedian age of males': '110'},
#  {'Area': '0.014 square miles',
#   'Average household size': '44.6 years',
#   'Average number of vehicles per apartment': '1.7',
#   'Average number of vehicles per house/condo': '14.5%',
#   'Crime index for the city': '65.4%',
#   'Median age of females': '44.1 years',
#   'Median household income': '$49,063',
#   'Median rent': '$695',
#   'Neighborhood Name': 'Adams-Place-Map',
#   'Percentage of foreign born residents': '8.6%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '2.5 people',
#   'Percentage of married-couple families': '32.3%',
#   'Percentage of married-couple families with children': '25.5%',
#   'Percentage of native residents born outside the US': '37.6%',
#   'Percentage of never married females Over 15': '28.2%',
#   'Percentage of never married males Over 15': '29.2%',
#   'Percentage of people born in another state': '39.4%',
#   'Percentage of people born in the state': '4.3%',
#   'Percentage of people that do not speak english': '19.8%',
#   'Percentage of single mother households': '11.6%',
#   'Percentage of units with a mortgage': '1.4',
#   'Population': '71',
#   'Population density': '4,925 people per square mile',
#   'Population of malesMedian age of males': '40'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': 'Addition-Davis-Island',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': '0.339 square miles',
#   'Average household size': '38.0 years',
#   'Average number of vehicles per apartment': '1.5',
#   'Average number of vehicles per house/condo': '25.0%',
#   'Crime index for the city': '62.9%',
#   'Median age of females': '34.2 years',
#   'Median household income': '$30,043',
#   'Median rent': '$708',
#   'Neighborhood Name': 'Additions-to-West-Tampa',
#   'Percentage of foreign born residents': '4.3%',
#   'Percentage of males in managment positions': '$112,546',
#   'Percentage of mamily households': '2.7 people',
#   'Percentage of married-couple families': '35.7%',
#   'Percentage of married-couple families with children': '30.4%',
#   'Percentage of native residents born outside the US': '20.9%',
#   'Percentage of never married females Over 15': '23.8%',
#   'Percentage of never married males Over 15': '19.9%',
#   'Percentage of people born in another state': '49.8%',
#   'Percentage of people born in the state': '13.7%',
#   'Percentage of people that do not speak english': '18.9%',
#   'Percentage of single mother households': '17.7%',
#   'Percentage of units with a mortgage': '1.1',
#   'Population': '2,298',
#   'Population density': '6,781 people per square mile',
#   'Population of malesMedian age of males': '1,033'},
#  {'Area': '0.003 square miles',
#   'Average household size': '41.4 years',
#   'Average number of vehicles per apartment': '1.9',
#   'Average number of vehicles per house/condo': '5.8%',
#   'Crime index for the city': '63.4%',
#   'Median age of females': '42.3 years',
#   'Median household income': '$82,750',
#   'Median rent': '$1,752',
#   'Neighborhood Name': 'Adeste-Condo',
#   'Percentage of foreign born residents': '8.2%',
#   'Percentage of males in managment positions': '$406,373',
#   'Percentage of mamily households': '2.3 people',
#   'Percentage of married-couple families': '44.5%',
#   'Percentage of married-couple families with children': '42.6%',
#   'Percentage of native residents born outside the US': '47.9%',
#   'Percentage of never married females Over 15': '7.6%',
#   'Percentage of never married males Over 15': '6.9%',
#   'Percentage of people born in another state': '38.0%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '7.2%',
#   'Percentage of single mother households': '35.6%',
#   'Percentage of units with a mortgage': '0.8',
#   'Population': '13',
#   'Population density': '4,972 people per square mile',
#   'Population of malesMedian age of males': '6'},
#  {'Area': '0.002 square miles',
#   'Average household size': '40.5 years',
#   'Average number of vehicles per apartment': '2.2',
#   'Average number of vehicles per house/condo': '36.4%',
#   'Crime index for the city': '39.1%',
#   'Median age of females': '35.5 years',
#   'Median household income': '$17,222',
#   'Median rent': '$537',
#   'Neighborhood Name': 'Airport-Business-Center',
#   'Percentage of foreign born residents': '8.1%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '2.2 people',
#   'Percentage of married-couple families': '49.3%',
#   'Percentage of married-couple families with children': '29.9%',
#   'Percentage of native residents born outside the US': '21.9%',
#   'Percentage of never married females Over 15': '28.1%',
#   'Percentage of never married males Over 15': '27.8%',
#   'Percentage of people born in another state': '33.6%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '8.4%',
#   'Percentage of single mother households': '21.0%',
#   'Percentage of units with a mortgage': '0.5',
#   'Population': '2',
#   'Population density': '1,031 people per square mile',
#   'Population of malesMedian age of males': '1'},
#  {'Area': '0.128 square miles',
#   'Average household size': '35.6 years',
#   'Average number of vehicles per apartment': '1.8',
#   'Average number of vehicles per house/condo': '37.6%',
#   'Crime index for the city': '61.5%',
#   'Median age of females': '38.4 years',
#   'Median household income': '$52,277',
#   'Median rent': '$762',
#   'Neighborhood Name': 'Airport-Service-Center',
#   'Percentage of foreign born residents': '11.3%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '2.4 people',
#   'Percentage of married-couple families': '36.5%',
#   'Percentage of married-couple families with children': '37.0%',
#   'Percentage of native residents born outside the US': '22.4%',
#   'Percentage of never married females Over 15': '31.9%',
#   'Percentage of never married males Over 15': '4.7%',
#   'Percentage of people born in another state': '28.7%',
#   'Percentage of people born in the state': '17.9%',
#   'Percentage of people that do not speak english': '8.2%',
#   'Percentage of single mother households': '11.2%',
#   'Percentage of units with a mortgage': '2.1',
#   'Population': '37',
#   'Population density': '290 people per square mile',
#   'Population of malesMedian age of males': '18'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': 'Al-Dana-Park',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': '0.105 square miles',
#   'Average household size': '60.5 years',
#   'Average number of vehicles per apartment': '1.7',
#   'Average number of vehicles per house/condo': '10.9%',
#   'Crime index for the city': '59.6%',
#   'Median age of females': '60.7 years',
#   'Median household income': '$101,461',
#   'Median rent': '$793',
#   'Neighborhood Name': 'Al-Mar',
#   'Percentage of foreign born residents': '2.1%',
#   'Percentage of males in managment positions': '$196,429',
#   'Percentage of mamily households': '32.2 people',
#   'Percentage of married-couple families': '38.8%',
#   'Percentage of married-couple families with children': '42.7%',
#   'Percentage of native residents born outside the US': '48.8%',
#   'Percentage of never married females Over 15': '17.5%',
#   'Percentage of never married males Over 15': '18.8%',
#   'Percentage of people born in another state': '38.3%',
#   'Percentage of people born in the state': '4.9%',
#   'Percentage of people that do not speak english': '21.2%',
#   'Percentage of single mother households': '31.5%',
#   'Percentage of units with a mortgage': '1.8',
#   'Population': '156',
#   'Population density': '1,492 people per square mile',
#   'Population of malesMedian age of males': '67'},
#  {'Area': '4',
#   'Average household size': '32.3 years',
#   'Average number of vehicles per apartment': '1.5',
#   'Average number of vehicles per house/condo': '11.2%',
#   'Crime index for the city': '74.6%',
#   'Median age of females': '27.9 years',
#   'Median household income': '$92,303',
#   'Median rent': '$1,466',
#   'Neighborhood Name': 'Alabany-Place-Condo',
#   'Percentage of foreign born residents': '0.4%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '21.0 people',
#   'Percentage of married-couple families': '13.9%',
#   'Percentage of married-couple families with children': '16.5%',
#   'Percentage of native residents born outside the US': '56.3%',
#   'Percentage of never married females Over 15': '31.6%',
#   'Percentage of never married males Over 15': '4.7%',
#   'Percentage of people born in another state': '32.2%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '33.0%',
#   'Percentage of single mother households': '45.9%',
#   'Percentage of units with a mortgage': '1.6',
#   'Population': 'density:Alabany',
#   'Population density': '6,868 people per square mile',
#   'Population of malesMedian age of males': '2'},
#  {'Area': '3',
#   'Average household size': '25.8 years',
#   'Average number of vehicles per apartment': '1.2',
#   'Average number of vehicles per house/condo': '11.2%',
#   'Crime index for the city': '70.3%',
#   'Median age of females': '29.5 years',
#   'Median household income': '$60,152',
#   'Median rent': '$1,066',
#   'Neighborhood Name': 'Albany-Villas-Townhomes',
#   'Percentage of foreign born residents': '0.4%',
#   'Percentage of males in managment positions': '242.5',
#   'Percentage of mamily households': '1.8 people',
#   'Percentage of married-couple families': '5.1%',
#   'Percentage of married-couple families with children': '8.0%',
#   'Percentage of native residents born outside the US': '56.3%',
#   'Percentage of never married females Over 15': '39.0%',
#   'Percentage of never married males Over 15': '11.5%',
#   'Percentage of people born in another state': '32.2%',
#   'Percentage of people born in the state': '0.0%',
#   'Percentage of people that do not speak english': '34.1%',
#   'Percentage of single mother households': '50.6%',
#   'Percentage of units with a mortgage': '1.4',
#   'Population': 'density:Albany',
#   'Population density': '10,166 people per square mile',
#   'Population of malesMedian age of males': '2'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': 'Alcazar-Condo',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'},
#  {'Area': 'NA',
#   'Average household size': 'NA',
#   'Average number of vehicles per apartment': 'NA',
#   'Average number of vehicles per house/condo': 'NA',
#   'Crime index for the city': 'NA',
#   'Median age of females': 'NA',
#   'Median household income': 'NA',
#   'Median rent': 'NA',
#   'Neighborhood Name': 'Alexandria-Place',
#   'Percentage of foreign born residents': 'NA',
#   'Percentage of males in managment positions': 'NA',
#   'Percentage of mamily households': 'NA',
#   'Percentage of married-couple families': 'NA',
#   'Percentage of married-couple families with children': 'NA',
#   'Percentage of native residents born outside the US': 'NA',
#   'Percentage of never married females Over 15': 'NA',
#   'Percentage of never married males Over 15': 'NA',
#   'Percentage of people born in another state': 'NA',
#   'Percentage of people born in the state': 'NA',
#   'Percentage of people that do not speak english': 'NA',
#   'Percentage of single mother households': 'NA',
#   'Percentage of units with a mortgage': 'NA',
#   'Population': 'NA',
#   'Population density': '242.5',
#   'Population of malesMedian age of males': 'NA'}]

# %%
df2=pd.DataFrame(total_data)
df2.set_index('Neighborhood Name', inplace=True)
df2.to_csv('DataAcquisition.csv')
df2.shape
#df2
# Out:
# (47, 24)

# %%
# %cat DataAcquisition.csv | head -10
# Out:
# Neighborhood Name,Area,Average household size,Average number of vehicles per apartment,Average number of vehicles per house/condo,Crime index for the city,Median age of females,Median household income,Median rent,Percentage of foreign born residents,Percentage of males in managment positions,Percentage of mamily households,Percentage of married-couple families,Percentage of married-couple families with children,Percentage of native residents born outside the US,Percentage of never married females Over 15,Percentage of never married males Over 15,Percentage of people born in another state,Percentage of people born in the state,Percentage of people that do not speak english,Percentage of single mother households,Percentage of units with a mortgage,Population,Population density,Population of malesMedian age of males
# 1000-Channelside-Condo,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,242.5,NA
# 1301-Soho-Condo,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,242.5,NA
# 1508-South-Howard-Condo,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,242.5,NA
# 1611-6th-Avenue-Townhomes,NA,34.9%,8.5%,2.2%,3.6%,13.2%,$880,1.6 people,7.7%,2.2%,24.4%,48.0%,32.5%,22.0%,1.3,12.3%,242.5,56.1%,1.1,7.2%,1.5%,NA,"$55,643",12.2%
# 2002-Dekle-Condo,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,242.5,NA
# 215-Verne-Condo,1,26.5%,242.5,89.7%,16.5%,27.1%,"$94,049","$1,267",1.6,6.0%,35.0%,37.4%,26.3%,1.7,30.1%,0.0%,8.3%,3.0%,58.5%,28.7%,29.2%,density:215,"1,709 people per square mile",1.9 people
# 2513-Maryland-Avenue-Condo,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,242.5,NA
# 1000-Channelside-Condo,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,242.5,NA
# 1000-Channelside-Condo,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,242.5,NA
